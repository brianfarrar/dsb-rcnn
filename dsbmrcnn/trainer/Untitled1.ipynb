# %%
import numpy as np
import cv2
import random
from matplotlib import pyplot as plt

import dsbhelper as dsb
import nuclei
import model as modellib
import dsbhelper
# Out:
# /Users/farrar/py3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
TEST_DATA = 'stage2_test'

# %%
# configure the trainer for inference
config = nuclei.InferenceConfig()

# %%
specimen_ids = dsb.get_specimen_ids(TEST_DATA)
print (specimen_ids[0])
# Out:
# 0019c086029dd3be01f72131edb74e21ee995574e6d5c136ea868630b0d73523

# %%
# set up the dataset and load validate data
dataset_val = nuclei.NucleiDataset()
dataset_val.load_data(TEST_DATA, mode='test', filter_ids=None)
dataset_val.prepare()

# %%
for i, image_id in enumerate(dataset_val.image_ids):

    print('Processing image #{}...'.format(i))
    # get image data (need specimen_id below)
    image_data = dataset_val.get_info(image_id)
    print('specimen_id: {}'.format(image_data['specimen_id']))
# Out:
# Processing image #0...
# specimen_id: 0019c086029dd3be01f72131edb74e21ee995574e6d5c136ea868630b0d73523
# Processing image #1...
# specimen_id: 004a078bb44ee55ee7d6f1c19f96b3a0d3b5037746a3a75197dbb0be06da05cf
# Processing image #2...
# specimen_id: 005463e6d4a0a0b21161f1d97392f22556fbddba970d9440ae774229308a91ed
# Processing image #3...
# specimen_id: 005af293e8e53218ae96746ecf9bb88b511154d4a0b35e4ec6296b4623e15836
# Processing image #4...
# specimen_id: 005d47447abac7f7fa0ac56ba82f13edbf485105baf0672504d84b58d562f38b
# Processing image #5...
# specimen_id: 00ac87390253a22f6eb67c5771a73050e06200d1aa682fcf1b1e3783b2944166
# Processing image #6...
# specimen_id: 00b4b9c026cfc91af21691503bad67081fc02d5c77b3cd27200d02dca6966b83
# Processing image #7...
# specimen_id: 00da4fe5346bbb36ccf178964a22fdf7e33888989624176a6af3b4a7cfd7da63
# Processing image #8...
# specimen_id: 00e36f2470960e84cfc9f0d30c1f76abd7b35e4516380bf74985cbe641086806
# Processing image #9...
# ...

# %%
img = dsb.get_specimen_image(TEST_DATA, 'b6a69c7dff77eafb65d364fe87ac7864d896940fc75bd441bde050ce6b640a52')
print (img.shape)
# Out:
# (304, 560, 3)

# %%
resize = cv2.resize(img, (512, 512))

# %%
print(resize.shape)
# Out:
# (512, 512, 3)
